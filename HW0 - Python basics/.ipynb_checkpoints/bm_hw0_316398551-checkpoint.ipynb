# %% [markdown]
# # **BM 33602795 - Technion - Medical Image Processing**
#
# ## **Homework 0 - Python basics**
# ---
#
# ### <a style='color:red'> Due Date: 31.3.2022 </a>

# %% [markdown]
# ### Agenda
#
# * Getting to Know Python
#     * [NumPy](#NumPy)
#     * [Matplotlib](#Matplotlib)
#
#
# #### Use as many cells as you need

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# ### Submission Guidelines
#
# * **No handwritten submissions.**
# * What you have to submit:
#     * You should submit this file only, with the name: `bm_hw0_id.ipynb`.
#     * No other file types (`.py`, `.docx`...) will be accepted.
# * Submission on the course website (Moodle).

# %% [markdown]
# ---

# %% [markdown]
# ### Keyboard Shortcuts
# * Run current cell: **Ctrl + Enter**
# * Run current cell and move to the next cell: **Shift + Enter**
# * Show lines in a code cell: **Esc + L**
# * View function documentation: **Shift + Tab** inside the parenthesis or `help(name_of_module)`
# * New cell below: **Esc + B**
# * Delete cell: **Esc + D, D** (two D's)
# * Change the type of a cell: **Esc + Y** changes the cell type to code, **Esc + M** changes the cell type to markdown, and **Esc + R** changes the cell type to raw.

# %% [markdown]
# ---

# %%
# imports you will need
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
seed = 0

# %% [markdown]
# <center> <img src="https://img.icons8.com/fluency/48/000000/python.png" width='60'>
#
# ## <center>Python

# %% [markdown]
# In this part, we are going to cover some of the basics in Python.<br>
#
# You may use Useful Resources section in the moodel for completing this assignment.

# %% [markdown]
# #### Printing in Python
# * There are several ways to print in python, here some of them:
#     * `print("a=", a)`
#     * `print(f'a={a}')` (highly recommended!)
#     * `print("a = {}".format(a))`
#     * `print("a=%s" % a)`
# * You can choose anyway you like or even mix them

# %% [markdown]
# ---

# %% [markdown]
# <center> <img src='https://tinyurl.com/5dbr5dev' width='60' >
#
#
# ## <center>NumPy

# %% [markdown]
# ### Exercise 1: Array Creation

# %% [markdown]
# 1. Create a 4X2 array filled with random values from a uniform distribution over [0,1).<br>
#    Print its shape, number of dimensions, and size.

# %%
np.random.seed(seed) #seed the generator 

# ====== YOUR CODE: ======
random_array = np.random.uniform(0,1,[4,2])
print("Array's shape:", random_array.shape)
print("Array's dimensions:", random_array.ndim)
print("Array's size:",random_array.size)
# ========================
# Out:
# Array's shape: (4, 2)
# Array's dimensions: 2
# Array's size: 8

# %% [markdown]
# 2. Return array of items by taking the second column from all rows of the array a.

# %%
a = np.array([[10 ,20, 30],
              [40, 50, 60],
              [70, 80, 90]])

# ====== YOUR CODE: ======
a_second_column = a[:, 1]
a_second_column
# ========================
# Out:
# array([20, 50, 80])

# %% [markdown]
# 3. Create a 3X3 array filled with ones and change the values of the first colunm to 5.

# %%
# ====== YOUR CODE: ======
ones_array = np.ones((3, 3))
ones_array[:, 0] = 5
ones_array
# ========================
# Out:
# array([[5., 1., 1.],
#        [5., 1., 1.],
#        [5., 1., 1.]])

# %% [markdown]
# 4. Create a 8X2 integer array in the range [70,150] such that the difference between each element is 5.

# %%
# ====== YOUR CODE: ======
a1 = [i for i in range(70, 106, 5)]
a2 = [j for j in range(110, 146, 5)]
a = np.array([a1, a2], dtype=int)
a

# ========================
# Out:
# array([[ 70,  75,  80,  85,  90,  95, 100, 105],
#        [110, 115, 120, 125, 130, 135, 140, 145]])

# %% [markdown]
# ### Exercise 2: Basic Operations

# %% [markdown]
# Let's define the arrays x,y :

# %%
x = np.array([[1,5],[2,6]], dtype=np.float64)
y = np.array([[3,6],[7,8]], dtype=np.float64)

# %% [markdown]
# 5. Print the transpose of array y.

# %%
# ====== YOUR CODE: ======
trans_y = np.transpose(y)
trans_y

# ========================
# Out:
# array([[3., 7.],
#        [6., 8.]])

# %% [markdown]
# 6. Perform element-wise multiplication of the arrays x and y.

# %%
# ====== YOUR CODE: ======
x_y_multi = x*y
x_y_multi
# ========================
# Out:
# array([[ 3., 30.],
#        [14., 48.]])

# %% [markdown]
# 7. Perform matrix multiplication of the arrays x and y, and print the maximum value of that product and its index.\
# Recommended functions for finding the index: `np.argwhere` or `np.unravel_index` and `np.argmax`.

# %%
# ====== YOUR CODE: ======
x_y_matmul = x @ y
print(f"The max value is: {np.max(x_y_matmul)} and its index is: {np.argmax(x_y_matmul)}")

# ========================
# Out:
# The max value is: 60.0 and its index is: 3

# %% [markdown]
# 8. Print the maximum from axis 0 and minimum from axis 1 of the array y.

# %%
# ====== YOUR CODE: ======
print(f"The max value of y in axis 0 is: {np.amax(y, axis=0)}")
print(f"The min value of y in axis 1 is: {np.amin(y, axis=1)}")

# ========================
# Out:
# The max value of y in axis 0 is: [7. 8.]
# The min value of y in axis 1 is: [3. 7.]

# %% [markdown]
# 9. Return an array of the elements from array x that are bigger or equal to 3.

# %%
# ====== YOUR CODE: ======
x3 = x[x>=3]
x3

# ========================
# Out:
# array([5., 6.])

# %% [markdown]
# 10. Square each element in array x and then add the array [4,3] to each row.

# %%
# ====== YOUR CODE: ======
squared_x = np.square(x)
squared_x[0,:]=squared_x[0,:]+[4,3]
squared_x[1,:]=squared_x[1,:]+[4,3]
squared_x

# ========================
# Out:
# array([[ 5., 28.],
#        [ 8., 39.]])

# %% [markdown]
# ---

# %% [markdown]
# <center> <img src='https://upload.wikimedia.org/wikipedia/commons/thumb/0/01/Created_with_Matplotlib-logo.svg/1024px-Created_with_Matplotlib-logo.svg.png' width='60' >
#
# ## <center>Matplotlib

# %% [markdown]
# ## Line Plots

# %% [markdown]
# Except for the examples of graphs in the Useful Resources section, below are additional graph types you can plot using matplotlib.

# %% [markdown]
# ### Scatter Plots

# %%
x = np.arange(50) * 2 * np.pi / 50
y = np.sin(x)
fig = plt.figure(figsize=(8, 5)) # create a figure, just like in matlab
ax = fig.add_subplot(1, 1 ,1) # create a subplot of certain size
ax.scatter(x, y, label="y = sin(x)")
ax.set_xlabel('index')
ax.set_ylabel("sin(x)")
ax.set_title("scatter sin(x)")
ax.grid()
ax.legend()

# %% [markdown]
# ### Bar Plots

# %%
fig = plt.figure(figsize=(10, 8)) # create a figure, just like in matlab
ax1 = fig.add_subplot(2, 1 ,1) # create a subplot of certain size
ax1.bar(x, y)
ax1.set_xlabel('x')
ax1.set_ylabel("y")
ax1.set_title("bar plot")
ax1.grid()

ax2 = fig.add_subplot(2, 1 ,2) # create a subplot of certain size
ax2.barh(x, y, height=x[1]-x[0])
ax2.set_xlabel('x')
ax2.set_ylabel("y")
ax2.set_title("barh plot")
ax2.grid()

plt.tight_layout()

# %% [markdown]
# ### Exercise 3: Line Plots
#
# Create 1000 values using `linspace` and plot $sin(x) + cos(x)$ both as `plot` and `scatter` in one figure (as 2 different subplots).

# %%
# ====== YOUR CODE: ======
x = np.linspace(1, 100, num=1000)
f = np.sin(x)+np.cos(x)

fig = plt.figure(figsize=(10, 8))

ax1 = fig.add_subplot(2, 1 ,1)
ax1.plot(x, f, label="y = sin(x)+cos(x)")
ax1.set_xlabel('x')
ax1.set_ylabel("sin(x)+cos(x)")
ax1.set_title("plot sin(x)+cos(x)")
ax1.grid()
ax1.legend()

ax2 = fig.add_subplot(2, 1 ,2)
ax2.scatter(x, f, label="y = sin(x)+cos(x)")
ax2.set_xlabel('x')
ax2.set_ylabel("sin(x)+cos(x)")
ax2.set_title("scatter sin(x)+cos(x)")
ax2.grid()
ax2.legend()

# ========================

# %% [markdown]
# ## Load and Display Images

# %% [markdown]
# ### Exercise 4: Load and Display Images

# %% [markdown]
# Read the image 'airballoon.jpg' and display it.<br>
# Set the figure size to (10,5) and add title. <br>
# Use matplotlib functions.

# %%
# ====== YOUR CODE: ======
airballoon = plt.imread('airballoon.jpg')
fig = plt.figure(figsize=(10, 5))
plt.imshow(airballoon)
plt.show()

# ========================
